# %%
import matplotlib.pyplot as plt
from matplotlib import colormaps
import pandas as pd

partitions = pd.read_csv("../build/partitions.csv", sep=', ', engine='python')


for l in partitions['level'].unique():
  particles = partitions[partitions['level'] == l]
  plt.figure()
  plt.xlim(-110, 110),
  plt.ylim(-110, 110)
  c_map = colormaps['jet']
  for p_id in particles['partition_id'].unique():
    p_id_tmp = p_id
    color = 0
    power = 0.25
    while p_id_tmp != 0:
      color = color + (p_id_tmp % 4) * power
      p_id_tmp = p_id_tmp // 4
      power = power / 4
    partition = particles[particles['partition_id'] == p_id]
    plt.scatter(partition['x'], partition['y'], color=c_map(color), label=f'Partition {p_id}')
    plt.title(f'Node level {l}' + (' / root' if l == 0 else ''))
    # plt.legend(loc='lower right')
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 26
#      22     partition = particles[particles['partition_id'] == p_id]
#      23     plt.scatter(partition['x'], partition['y'], color=c_map(color), label=f'Partition {p_id}')
#      24     plt.title(f'Node level {l}' + (' / root' if l == 0 else ''))
#      25     # plt.legend(loc='lower right')
# ---> 26   plt.show()
#
# File /usr/lib/python3.14/site-packages/matplotlib/pyplot.py:613, in show(*args, **kwargs)
#     569 """
#     570 Display all open figures.
#     571
#    (...)    610 explicitly there.
#     611 """
#     612 _warn_if_gui_out_of_main_thread()
# --> 613 return _get_backend_mod().show(*args, **kwargs)
#
# File /usr/lib/python3.14/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ...
